# %%
# %matplotlib notebook

# %%
#Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
from pathlib import Path
crime_data_to_load=Path("/Users/Nico/Documents/Resources/Starter_Code/crime-data-from-2010-to-present.csv")
crime_data_df = pd.read_csv(crime_data_to_load, parse_dates=["Date Reported","Date Occurred"])

# %%
res=[]
for row in crime_data_df.iterrows():
    date = (row[1]["Date Occurred"])
    year,month,day,time=(date.year,date.month,date.day,row[1]["Time Occurred"])
    time=str(time)
    hour,minute=time[:2],time[2:]
    d = datetime.datetime(year=year, month=month, day=day, hour = int(hour) ,minute = int(minute))
    res.append(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43720\3858408499.py in <module>
#       5     time=str(time)
#       6     hour,minute=time[:2],time[2:]
# ----> 7     d = datetime.datetime(year=year, month=month, day=day, hour = int(hour) ,minute = int(minute))
#       8     res.append(d)
#       9
#
# ValueError: hour must be in 0..23

# %%
crime_data_df["hour occurred"] = crime_data_df["Time Occurred"].apply(lambda x: int(str(x)[:2]))

# %%
crime_data_df.loc[:, "datetime occurred"]=res
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43720\1609074853.py in <module>
# ----> 1 crime_data_df.loc[:, "datetime occurred"]=res
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     714
#     715         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716         iloc._setitem_with_indexer(indexer, value, self.name)
#     717
#     718     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1626                         if com.is_null_slice(indexer[0]):
#    1627                             # We are setting an entire column
# -> 1628                             self.obj[key] = value
#    1629                             return
#    1630                         elif is_array_like(value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3653         else:
#    3654             # set column
# -> 3655             self._set_item(key, value)
#    3656
#    3657     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3830         ensure homogeneity.
#    3831         """
# -> 3832         value = self._sanitize_column(value)
#    3833
#    3834         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4536
#    4537         if is_list_like(value):
# -> 4538             com.require_length_match(value, self.index)
#    4539         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4540
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     555     """
#     556     if len(data) != len(index):
# --> 557         raise ValueError(
#     558             "Length of values "
#     559             f"({len(data)}) "
#
# ValueError: Length of values (326) does not match length of index (1993259)

# %%
crime_data_df["datetime occurred"].head()

# %%
#Total number of unique area names
area_name_count=len(crime_data_df["Area Name"].unique())
area_name_count

# %%
#Total number of Crime Code Description
crime_count=len(crime_data_df["Crime Code Description"].unique())
crime_count

# %%
#Find the most common geographical area name in LA County
most_common_area=crime_data_df["Area Name"].value_counts()
most_common_area

# %%
#What area name has the least committed amount of crimes?
least_common_area=crime_data_df["Area Name"].value_counts(ascending=True)
least_common_area

# %%
#crime_type=crime_data_df[crime_data_df['Crime Code']].groupby(['Area Name'])

# %%
#Find the highest amount of homicides by Area Name
homicide_count=crime_data_df[crime_data_df['Crime Code']==110].groupby(['Area Name'])['DR Number'].count()
sorted_homicide=homicide_count.sort_values(ascending=False)
sorted_homicide
# Out:
# Area Name
# 77th Street    422
# Southeast      363
# Newton         229
# Southwest      212
# Hollenbeck     157
# Harbor         156
# Rampart        139
# Mission        128
# Foothill       111
# Central         98
# Northeast       86
# Olympic         79
# N Hollywood     76
# Hollywood       66
# Van Nuys        58
# Wilshire        55
# West Valley     52
# Pacific         48
# Devonshire      39
# Topanga         36
# West LA         24
# Name: DR Number, dtype: int64

# %%
crime_max=crime_data_df.groupby("Area Name")["Crime Code"].max()

merge_max=pd.merge(crime_data_df, crime_max, how="right", on=["Area Name", "Crime Code"])

# %%
#Cleaning up the data
#crime_data=crime_data.dropna(how='any')
#crime_data.head()

# %%
#Diplay a data table of the mean, median, and SEM of crime offenders' age who committed homicide
mean=crime_data_df['Victim Age'].groupby(crime_data_df['Area Name']).mean()
median=crime_data_df['Victim Age'].groupby(crime_data_df['Area Name']).median()
sem=crime_data_df['Victim Age'].groupby(crime_data_df['Area Name']).sem()


summary_stat=pd.DataFrame({"Mean of Victim Age":mean,
                          "Median of Victim Age":median,
                          "Victim Age Std. Err":sem})
#colors=['blue', 'red', 'yellow']
#df_colors=[mean, median, sem]
#for i, df_colors in enumerate(df_colors):
    #df_colors.plot(kind="bar", x="Area Name", y="Victim Age", colors=colors[i])
    #plot.show()

# %%
#Display bar graph of the Median of Victim Age
median=crime_data_df['Victim Age'].groupby(crime_data_df['Area Name']).median()
median_stat=pd.DataFrame({"Median of Victim Age":median})

plot_pandas=median_stat.plot.bar(color='b')
plt.xlabel("Area Name")
plt.ylabel("Victim Age")
plt.title("Median of Victim's Age per Area Name")

# %%
#Display bar graph of the Mean of Victim Age
mean=crime_data_df['Victim Age'].groupby(crime_data_df['Area Name']).mean()
mean_stat=pd.DataFrame({"Median of Victim Age":median})

plot_pandas=mean_stat.plot.bar(color='r')
plt.xlabel("Area Name")
plt.ylabel("Victim Age")
plt.title("Mean of Victim's Age per Area Name")

# %%
# Scattplot of the Homicides vs Time
homicide_data = crime_data_df.loc[crime_data_df["Crime Code"] == 110]
homicide_data
#m_crime =homicide_data.groupby("Crime Code")["Time Occurred"].mean()
#om_time = homicide_data.groupby("Crime Code")["Area Name"].mean()
# x_axis = hom_crime
# y_axis = hom_time
# plt.scatter(x_axis,y_axis)
# plt.xlabel("Time Occurred")
# plt.ylabel("Area Name")
# plt.title("Homicide average age vs area")
# plt.show()

# %%
#What are the most crimes being committed?

#What time of the day is this crime occurring the most?

#Provide a dataset of the crimes committed by men vs women 
crime_data_df= crime_data_df.astype({"Premise Code":str}, errors="raise")
crime_data_df["Premise Code"].dtype
# Out:
# dtype('O')

# %%
#What ethnicities have the highest victim counts?
eth_count = crime_data_df["Victim Descent"].value_counts()
eth_count.head(10)

eth_df= pd.DataFrame({
    "Ethnicity":["Hispanic", "White", "Black", "Other", "Unknown","Asian"],
    "Victims Per Ethnicity": [685420, 483035, 316944, 191600, 68234, 47941]
})

eth_df.head(6)
# Out:
#   Ethnicity  Victims Per Ethnicity
# 0  Hispanic                 685420
# 1     White                 483035
# 2     Black                 316944
# 3     Other                 191600
# 4   Unknown                  68234
# 5     Asian                  47941

# %%
# Bar Chart visiual of victims per ethnicity
eth_df.plot (kind = "bar", color=("g"))
plt.xlabel("Ethnicity Info")
plt.xticks(rotation = 90)
plt.ylabel("Vitcims Ethnicity")
plt.show()


#Types of Crimes -  Average(s) for race?  | bell curve that dispalays crimes occured by race and those averages.


#Use line charts to the 3 highest races in relation to crimes being committed
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Types of Crimes -  Average(s) for race?  | bell curve that dispalays crimes occured by race and those averages.
# stats_df = crime_data_df.groupby("Victim Descent")["Crime Code"].max()
# stats_df

# merge_stats= pd.merge(crime_data_df, stats_df, how="right", on=["Victim Descent","Crime Code"])
# print(merge_stats)

#converted_df=crime_data_df[["Victim Descent","Crime Code"]].head()
#converted_df
# Out:
#   Victim Descent  Crime Code
# 0            NaN         510
# 1            NaN         510
# 2            NaN         510
# 3            NaN         510
# 4            NaN         510

# %%
#Create a DataFrame that contains the most frequent crime code for each ethnicity in Victim Descent

#Combine the Victim Descent and Crime Code columns
ethnicity_group = crime_data_df.groupby(["Victim Descent", "Crime Code"]).size().reset_index(name= "counts")

#Find the Max for each Victim Descent
max_counts = ethnicity_group.groupby("Victim Descent")["counts"].agg("max")

#Merge the combined data with the max count for Victim descent
crime_result = pd.merge(ethnicity_group, max_counts, on="Victim Descent", suffixes = ("", "_max"))

crime_result = crime_result[crime_result["counts"] == crime_result["counts_max"]]

crime_result = crime_result.drop(columns=["counts_max"])

cleaned_crime_result = crime_result.query("counts >= 10000")
cleaned_crime_result
# Out:
#      Victim Descent  Crime Code  counts
# 177               B         624   45217
# 487               H         624   81094
# 783               O         310   20913
# 1041              W         330   52427
# 1196              X         442   12271

# %%
cleaned_crime_result.sort_values(by="counts")
# Out:
#      Victim Descent  Crime Code  counts
# 1196              X         442   12271
# 783               O         310   20913
# 177               B         624   45217
# 1041              W         330   52427
# 487               H         624   81094

# %% [markdown]
# Note: create visualization to show top crime codes per victim descent. What were the top areas were the top areas for 624's

# %%
cleaned_crime_result.plot.bar(x= "Victim Descent", y = "counts", color= "Crime Code")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9748\2585262518.py in <module>
# ----> 1 cleaned_crime_result.plot.bar(x= "Victim Descent", y = "counts", color= "Crime Code")
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1129         other axis represents a measured value.
#    1130         """
# -> 1131         return self(kind="bar", x=x, y=y, **kwargs)
#    1132
#    1133     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     327         self._compute_plot_data()
#     328         self._setup_subplots()
# --> 329         self._make_plot()
#     330         self._add_table()
#     331         self._make_legend()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1495         import matplotlib as mpl
#    1496
# -> 1497         colors = self._get_colors()
#    1498         ncolors = len(colors)
#    1499
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _get_colors(self, num_colors, color_kwds)
#     840             num_colors = self.nseries
#     841
# --> 842         return get_standard_colors(
#     843             num_colors=num_colors,
#     844             colormap=self.colormap,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\style.py in get_standard_colors(num_colors, colormap, color_type, color)
#      68         return color
#      69
# ---> 70     colors = _derive_colors(
#      71         color=color,
#      72         colormap=colormap,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\style.py in _derive_colors(color, colormap, color_type, num_colors)
#     124                 "'color' and 'colormap' cannot be used simultaneously. Using 'color'"
#     125             )
# --> 126         return _get_colors_from_color(color)
#     127     else:
#     128         return _get_colors_from_color_type(color_type, num_colors=num_colors)
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\style.py in _get_colors_from_color(color)
#     170
#     171     color = cast(Collection[Color], color)
# --> 172     return list(_gen_list_of_colors_from_iterable(color))
#     173
#     174
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\style.py in _gen_list_of_colors_from_iterable(color)
#     203             yield x
#     204         else:
# --> 205             raise ValueError(f"Invalid color {x}")
#     206
#     207
#
# ValueError: Invalid color Crime Code

# %%
# Create a Bar chart for the clean_crime_result dataframe

Victim_Descent = ["Black", "Hispanic", "Unknown", "White", "Not Reported"]
Crime_code_frequency= [45217, 81094, 20913, 52427, 12271]
crime_codes = (624, 624, 310, 330, 442)
x_axis = Victim_Descent

#Create a bart chart based upon the above data

plt.bar(x_axis, Crime_code_frequency, color="b", align="center")
plt.xticks(x_axis, Victim_Descent)
plt.title("Highest Crime Code Frequency per Victim Descent")
plt.legend(crime_codes,loc="best")
plt.show()

# %%
#What type of crime is least committed per area compared to the other neighborhoods?
homicide_count=crime_data_df[crime_data_df['Crime Code']==110].groupby(['Area Name'])['DR Number'].count()
sorted_homicide=homicide_count.sort_values(ascending=False)
sorted_homicide
#What geographical area has the least amount of crimes?
